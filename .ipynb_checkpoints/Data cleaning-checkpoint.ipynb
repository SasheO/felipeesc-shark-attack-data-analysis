# %%
import pandas as pd
import os
from datetime import datetime
import re
import numpy as np
# Out:
# C:\Users\sashe\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\sashe\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (

# %%
# # import kagglehub
# Download latest version
# path = kagglehub.dataset_download("felipeesc/shark-attack-dataset")
# print("Path to dataset files:", path)

# files already downloaded so i saved it in a file
with open("path.txt", "r") as f:
    path = f.read()

# %%
os.listdir(path)
# Out:
# ['attacks.csv', 'list_coor_australia.csv']

# %%
attacks_df = pd.read_csv(path+'/attacks.csv', encoding_errors='ignore')
list_coor_australia_df = pd.read_csv(path+'/list_coor_australia.csv')

# %%
len(attacks_df)
# Out:
# 25723

# %%
list(attacks_df) # column titles
# Out:
# ['Case Number',
#  'Date',
#  'Year',
#  'Type',
#  'Country',
#  'Area',
#  'Location',
#  'Activity',
#  'Name',
#  'Sex ',
#  'Age',
#  'Injury',
#  'Fatal (Y/N)',
#  'Time',
#  'Species ',
#  'Investigator or Source',
#  'pdf',
#  'href formula',
#  'href',
#  'Case Number.1',
#  'Case Number.2',
#  'original order',
#  'Unnamed: 22',
#  'Unnamed: 23']

# %%
attacks_df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity            Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling     Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  AdysonMcNeely     F  ...
# 2                    Habush, Oahu      Surfing     John Denges    M  ...
# 3              Arrawarra Headland      Surfing            male    M  ...
# 4                        La Ticla  Free diving  Gustavo Ramos     M  ...
#
# ...

# %% [markdown]
# # STEPS:
#
# 1. Eye ball data
# - reveals that case number = date = case number 1 = case number 2, redundant with year
#     - further analysis reveals taht case number is more standardised than date object so will keep it for now
# - can delete case number 1 and 2 and year, convert date to datetime object. cases are uniquely identified by original order already
# - there are trailing >20000 rows with mostly null or nan values except a 0 value in the first column
# - what are the unnamed 1 and 2 columns? nothing important. can delete
# - href, href formula, pdf columns are similar. href columns are "http://sharkattackfile.net/spreadsheets/pdf_directory/" + pdf column
# - can delete href and href column
#
# 2. check if data types of columns are optimal or need to be converted to make sense. always remove leading and trailing spaces
# 3. check if data that doesn't make sense because it isn't standardised e.g. united states being represented as US in the same column

# %% [markdown]
# # Drop excessivly sparse rows or redundant columns

# %%
# drop duplicate or redundant columns. keep only one of the needed ones
attacks_df.drop(axis=1, labels=['Case Number.1','Case Number.2', 'Year'], inplace=True)

# %%
# NOTE these give high null percentages due to trailing 0s in first column
# print(attacks_df.isnull().all(axis=0)) # find columns with all nan --> there are none
print(attacks_df.isnull().sum()/len(attacks_df)) # count nan in columns and find fraction
# Out:
# Case Number               0.661704
# Date                      0.755005
# Type                      0.755161
# Country                   0.756949
# Area                      0.772694
# Location                  0.775998
# Activity                  0.776154
# Name                      0.763169
# Sex                       0.776970
# Age                       0.865062
# Injury                    0.756094
# Fatal (Y/N)               0.775959
# Time                      0.885394
# Species                   0.865335
# Investigator or Source    0.755666
# pdf                       0.755005
# href formula              0.755044
# href                      0.755005
# original order            0.754733
# Unnamed: 22               0.999961
# Unnamed: 23               0.999922
# dtype: float64

# %%
# discover what unnamed columns represent by finding unique vaules
print(attacks_df['Unnamed: 22'].unique())
print(attacks_df['Unnamed: 23'].unique())

# drop sparse columns
attacks_df.drop(axis=1, labels=['Unnamed: 22', 'Unnamed: 23'], inplace=True)
# Out:
# <ArrowStringArray>
# [nan, 'stopped here']
# Length: 2, dtype: str
# <ArrowStringArray>
# [nan, 'Teramo', 'change filename']
# Length: 3, dtype: str

# %%
# difference between href and href formula? 
(attacks_df['href'] == attacks_df['href formula']).sum() # 6242 of 6302 are the same. the fields approximate each other . though total number of rows is 22000, most are trailing 0s after aboht 6000
attacks_df.drop(axis=1, labels=['href', 'href formula'], inplace=True) # drop them, keep 'pdf'

# %%
# drop rows with mostly nan values
attacks_df.dropna(axis=0,thresh=7, inplace=True) # drop values with at least threshold 7 i.e. less than 40% of fields are non-na values

# %%
# check again
# print(attacks_df.isnull().all(axis=0)) # find columns with all nan --> there are none
print(attacks_df.isnull().sum()/len(attacks_df)) # count nan in columns and find fraction
# Out:
# Case Number               0.000159
# Date                      0.000000
# Type                      0.000635
# Country                   0.007934
# Area                      0.072199
# Location                  0.085687
# Activity                  0.086322
# Name                      0.033323
# Sex                       0.089654
# Age                       0.449222
# Injury                    0.004443
# Fatal (Y/N)               0.085528
# Time                      0.532212
# Species                   0.450333
# Investigator or Source    0.002698
# pdf                       0.000000
# original order            0.000000
# dtype: float64

# %%
attacks_df
# Out:
#      Case Number         Date        Type             Country  \
# 0     2018.06.25  25-Jun-2018     Boating                 USA
# 1     2018.06.18  18-Jun-2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018    Provoked              MEXICO
# ...          ...          ...         ...                 ...
# 6297     ND.0005  Before 1903  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905  Unprovoked                 USA
# 6300     ND.0002    1883-1889  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# ...

# %% [markdown]
# # Convert data to accurate data types, remove leading or trailing spaces

# %%
attacks_df.dtypes # find data types
# Out:
# Case Number                   str
# Date                          str
# Type                          str
# Country                       str
# Area                          str
# Location                      str
# Activity                      str
# Name                          str
# Sex                           str
# Age                           str
# Injury                        str
# Fatal (Y/N)                   str
# Time                          str
# Species                       str
# Investigator or Source        str
# pdf                           str
# original order            float64
# dtype: object

# %%
type(attacks_df)
# Out:
# pandas.DataFrame

# %%
# remove leading and trailing spaces
attacks_df = attacks_df.map(lambda x: x.strip() if isinstance(x, str) else x)

# %% [markdown]
# ## convert str to date type for 'Date' value
#
# ### Notes
# -> In 'Date' column:
#
# most are dd-mmm-yyyy
#
# some are "Reported dd-mmm-yyyy" month in text
#
# some are "yyyy.dd.mm" month in numbers
#
# some are 'Fall 2008' or 'Summer-2008'
#
# some are 'Early Aug-2006'
#
# 19-Jul-2004 Reported to have happened  "on the weekend
#
#
# -> seems like 'Case Number' column is way more standardized than 'Date' column
#
# yyyy.mm.dd(.x)(.R)
# - where mm can be 00 if the month isn't known and dd can also by 00 if the day isn't known
# - where .R apprears if the instance was reported on the given day but did not necessarily happen that day
# - where .x can be any lower case letter to differentiate between two or more instances that happened on the same day e.g. 2018.05.13.b and 2018.05.13.a
#
# 0000.yyyy where year is B.C.
#
# ND-nnnn or ND.nnnn
# - where nnnn is a four digit number that uniquely identifies an undated incident e.g. 'Between   1951-1963', '2009?'

# %%
'''
To find how many months or days are unknown out of 6000 -> to see if they are so few they can be discarded

This cell is mostly LLM generated code which I modified
'''

missing_month_pattern = r'^\d{4}\.00\.\d{2}(?:\.[a-z])?(?:\.R)?$'
missing_day_pattern = r'^\d{4}\.\d{2}\.00(?:\.[a-z])?(?:\.R)?$'

def count_date_matching_pattern(df, pattern, case_column='Case Number'):
    """
    Count the number of case numbers with unknown months (mm = 00)
    in the format yyyy.mm.dd(.x)(.R)
    
    Parameters:
    df (pd.DataFrame): Input dataframe
    case_column (str): Name of the column containing case numbers
    
    Returns:
    int: Count of unknown months
    """
    count = 0
    matching_cases = []
    
    for case in df[case_column].dropna():
        case_str = str(case).strip()
        
        # Pattern for yyyy.00.dd format with optional suffixes
        # This looks for month = 00 in the date pattern
        
        
        if re.match(pattern, case_str):
            count += 1
            matching_cases.append(case_str)
    
    return count, matching_cases

# %%
print("Unknown days:", count_date_matching_pattern(attacks_df, missing_day_pattern)[0])
print("Unknown months:", count_date_matching_pattern(attacks_df, missing_month_pattern)[0])
# Out:
# Unknown days: 742
# Unknown months: 397

# %%
'''
This cell is LLM generated but modified by me. 

prompt for LLM to write initial code:
Hey, I am working on a dataset in Python pandas. I am trying to create a datetime column named "Date (datetime)" from an existing string "Case Number" column. 
The format of the data in "Case Number" is either:
yyyy.mm.dd(.x)(.R) 
- where mm can be 00 if the month isn't known and dd can also by 00 if the day isn't known
- where .R apprears if the instance was reported on the given day but did not necessarily happen that day
- where .x can be any lower case letter to differentiate between two or more instances that happened on the same day e.g. 2018.05.13.b and 2018.05.13.a

0000.yyyy where year is B.C.

ND-nnnn or ND.nnnn
- where nnnn is a four digit number that uniquely identifies an undated incident e.g. 'Between   1951-1963', '2009?'

Could you write me code or a function to create a new datetime column named "Date (datetime)"?
'''
def parse_case_number_to_datetime(case_number):
    """
    Convert case number string to datetime object based on various formats.
    
    Parameters:
    case_number (str): The case number string to parse
    
    Returns:
    datetime or NaT: Parsed datetime or NaT if parsing fails
    """
    if pd.isna(case_number) or case_number is None:
        return pd.NaT
    
    # Convert to string and strip whitespace
    case_str = str(case_number).strip()
    
    # Handle empty strings
    if case_str == '':
        return pd.NaT
    
    # Pattern 1: yyyy.mm.dd format with optional .x and .R suffixes
    # Examples: 2018.05.13, 2018.05.13.b, 2018.05.13.R, 2018.05.13.b.R
    pattern1 = r'^(\d{4})\.(\d{2})\.(\d{2})(?:\.([a-z]))?(?:\.(R))?$'
    match = re.match(pattern1, case_str)
    
    if match:
        year, month, day, letter, reported = match.groups()
        year = int(year)
        month = int(month)
        day = int(day)
        
        # Handle unknown month or day (00)
        if month == 0:
            return pd.NaT # unknown month is only 300/6302, <5% so discard
        if day == 0:
            day = 1    # keeping known months but unknown day seems more important since 742/6302, >10% are affected. this won't negatively affect analysis anyway
            
        try:
            return datetime(year, month, day)
        except ValueError:
            return pd.NaT
    
    # Pattern 2: 0000.yyyy (BC years)
    pattern2 = r'^0000\.(\d{4})$'
    match = re.match(pattern2, case_str)
    
    if match:
        year = int(match.group(1))
        return pd.NaT  # BC dates can't be directly represented in pandas datetime
    
    # Pattern 3: ND-nnnn or ND.nnnn (Undated incidents)
    pattern3 = r'^ND[.-](\d{4})$'
    match = re.match(pattern3, case_str)
    
    if match:
        return pd.NaT

    # If no patterns match, return NaT
    return pd.NaT

# %%
attacks_df['Date (datetime)'] = attacks_df['Case Number'].apply(parse_case_number_to_datetime)

# %%
attacks_df
# Out:
#      Case Number         Date        Type             Country  \
# 0     2018.06.25  25-Jun-2018     Boating                 USA
# 1     2018.06.18  18-Jun-2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018    Provoked              MEXICO
# ...          ...          ...         ...                 ...
# 6297     ND.0005  Before 1903  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905  Unprovoked                 USA
# 6300     ND.0002    1883-1889  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# ...

# %%
# find number of dates in column of 6302
print(len(attacks_df[attacks_df['Date (datetime)'].notna()]), "non-NaT dates of", len(attacks_df), "total")
# Out:
# 5733 non-NaT dates of 6302 total

# %% [markdown]
# ## TODO: create new column for time that separates into morning, afternoon, evening and night. Probably an llm could help with allocating the time

# %% [markdown]
# # Standardise data
#
# Check if data that doesn't make sense because it isn't standardised e.g. united states being represented as US in the same column
#
# ### Notes
# ->  find unique values of different data columns and eye ball them
#
# -> # TODO: deal with each case

# %%
unique_values = {}
for column in list(attacks_df):
    unique_values[column] = list(pd.unique(attacks_df[column]))

# %%
unique_values.keys()
# Out:
# dict_keys(['Case Number', 'Date', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ', 'Investigator or Source', 'pdf', 'original order', 'Date (datetime)'])

# %%
'''
'Boating' = 'Boat' = 'Boatomg'

Replace with boat
'''
unique_values['Type']
# Out:
# ['Boating',
#  'Unprovoked',
#  'Invalid',
#  'Provoked',
#  'Questionable',
#  'Sea Disaster',
#  nan,
#  'Boat',
#  'Boatomg']

# %%
'''
'CEYLON' = 'CEYLON (SRI LANKA)' = 'SRI LANKA'

'FIJI'='Fiji',

'MALDIVE ISLANDS'= 'MALDIVES',

'ST. MAARTIN' = 'ST. MARTIN'

'Seychelles' = 'SEYCHELLES'

'Sierra Leone' = "SIERRA LEONE"

'UNITED ARAB EMIRATES' = 'UNITED ARAB EMIRATES (UAE)'

'REUNION' = 'REUNION ISLAND'

there's more but this suffices
'''
column = 'Country'
try:
    for indx in range(len(unique_values[column])):
        if type(unique_values[column][indx])==float:
            unique_values[column].pop(indx)
except Exception as e:
    print(e)

sorted(unique_values[column])
# Out:
# ['ADMIRALTY ISLANDS',
#  'AFRICA',
#  'ALGERIA',
#  'AMERICAN SAMOA',
#  'ANDAMAN / NICOBAR ISLANDAS',
#  'ANDAMAN ISLANDS',
#  'ANGOLA',
#  'ANTIGUA',
#  'ARGENTINA',
#  'ARUBA',
#  'ASIA?',
#  'ATLANTIC OCEAN',
#  'AUSTRALIA',
#  'AZORES',
#  'BAHAMAS',
#  'BAHREIN',
#  'BANGLADESH',
#  'BARBADOS',
#  'BAY OF BENGAL',
#  'BELIZE',
#  'BERMUDA',
#  'BRAZIL',
#  'BRITISH ISLES',
#  'BRITISH NEW GUINEA',
#  'BRITISH VIRGIN ISLANDS',
#  'BRITISH WEST INDIES',
#  'BURMA',
#  'Between PORTUGAL & INDIA',
#  'CANADA',
#  'CAPE VERDE',
#  'CARIBBEAN SEA',
#  'CAYMAN ISLANDS',
#  'CENTRAL PACIFIC',
#  'CEYLON',
#  'CEYLON (SRI LANKA)',
#  'CHILE',
#  'CHINA',
#  'COLUMBIA',
#  'COMOROS',
#  'COOK ISLANDS',
#  'COSTA RICA',
#  'CRETE',
#  'CROATIA',
#  'CUBA',
#  'CURACAO',
#  'CYPRUS',
#  'Coast of AFRICA',
#  'DIEGO GARCIA',
#  'DJIBOUTI',
#  'DOMINICAN REPUBLIC',
#  'ECUADOR',
#  'EGYPT',
#  'EGYPT / ISRAEL',
#  'EL SALVADOR',
#  'ENGLAND',
#  'EQUATORIAL GUINEA / CAMEROON',
# ...

# %%
column = 'Area'
try:
    for indx in range(len(unique_values[column])):
        if type(unique_values[column][indx])==float:
            unique_values[column].pop(indx)
except Exception as e:
    print(e)

sorted(unique_values[column])
# Out:
# list index out of range
# ['"Head of the Gulf"',
#  '(Southwestern Pacific)',
#  '04.05N-13.23W',
#  '1,000 miles east of Hawaii',
#  '1000 miles west of Hawaii',
#  '10S, 142E',
#  '12 miles off the north coast',
#  '150 miles offshore',
#  '165  miles from Bermuda',
#  '180 miles southeast of Okinawa',
#  '18S / 50E',
#  '19S, 178?E',
#  '2 to 3 miles off Taboguilla Island, Pacific Ocean',
#  '200 nm southeast of Manila',
#  '22N, 88E',
#  '25 km off the coast of Iran & 483km from mouth of Persian Gulf',
#  "250 miles southwest of O'ahu, Hawaii",
#  '30 nm from Singapore',
#  '300 miles east of Luzon',
#  '300 miles east of Mauritius',
#  '300 miles east of St. Thomas (Virgin Islands)',
#  '300 miles from Antigua',
#  '330 to 350 miles east of Wake Island',
#  '33N, 68W',
#  "3539 : 1658'",
#  '40 miles off Grand Bahama Island',
#  '40 miles south of Naples',
#  '400 miles southeast of Sri Lanka',
#  '5aint-Denis',
#  '60 miles north of San Domingo in the West Indies',
# ...

# %%
unique_values['Location'] # nothing to see here
# Out:
# ['Oceanside, San Diego County',
#  'St. Simon Island, Glynn County',
#  'Habush, Oahu',
#  'Arrawarra Headland',
#  'La Ticla',
#  'Flat Rock, Ballina',
#  'Piedade Beach, Recife',
#  'Lighhouse Point Park, Ponce Inlet, Volusia County',
#  'Cocoa Beach, Brevard  County',
#  'Daytona Beach, Volusia County',
#  'Cairns Aquarium',
#  'Isle of Palms,  Charleston County',
#  'Hilton Head Island, Beaufort County',
#  "Off Land's End",
#  'Dugong Bay',
#  'Nahoon Beach, East London',
#  'Sharpes Beach, Ballina',
#  'Sai Noi Beach',
#  'Manuelita',
#  'Gearys Beach',
#  'Lennox Head',
#  'Surfers Point, Prevelly',
#  'South Point, Gracetown',
#  'Madoogali',
#  'Robberg Beach, Plettenberg Bay',
#  'Shipwrecks Beach, Keoneloa Bay, Kauai',
#  'Piedade',
#  'Lefthanders, Margaret River Area',
#  'Cobblestones, Margaret River Area',
#  'Nirvana Beach',
#  'Praia de Sauauhy, Macei',
#  'Magenta Beach, Noumea',
#  'Bimini',
#  'St. Francis Bay',
#  'Kukio Beach',
#  "Waterman's Bay",
#  'Lorne',
# ...

# %%
'''
There's a lot to glean from here but not sure if it is worth doing
Circle back when analysing
'''

column = 'Activity'
try:
    count = 0
    for indx in range(len(unique_values[column])):
        if type(unique_values[column][indx])==float:
            unique_values[column].pop(indx-count)
            count += 1
except Exception as e:
    print(e)

sorted(unique_values[column])
# Out:
# list index out of range
# ['',
#  '"Boat accident"',
#  '"Climbing up to ship after repairing the stern in water"',
#  '"Crossing the river"',
#  '"Flying Tiger" transport plane went down with 5 men onboard',
#  '"Riding waves on a board"',
#  '"Swimming vigorously"',
#  '.',
#  "12 of the Penang's crew were returning to the ship when their 12' dinghy capsized",
#  '13 men in the water after sailboat capsized & sank',
#  '14 m prawn trawler New Venture capsized  & sank in heavy seas Three people in the water',
#  '1446-ton Norwegian barque Errol, bound from Peru to Newcastle with 22 on board wrecked. Survivors shelterd on the wreck of the Annasona. Subsequently the Master, his wife & 4 children perished along with several crew. Survivors (5) were rescued 7/12/1909',
#  "16' catamaran capsized previous night, occupants stayed with wreckage until morning, then attempted to swim ashore",
#  '17 Maldivians adrift in open boat for 31 days',
#  '2 boats capsized',
# ...

# %%
'''
delete 'lli' and '.'
convert 'N' to 'M'
'''
unique_values['Sex ']
# Out:
# ['F', 'M', nan, 'lli', 'N', '.']

# %%
'''
There's a lot to glean from here but not sure if it is worth doing
Circle back when analysing
'''

unique_values['Injury']
# Out:
# ['No injury to occupant, outrigger canoe and paddle damaged',
#  'Minor injury to left thigh',
#  'Injury to left lower leg from surfboard skeg',
#  'Minor injury to lower leg',
#  'Lacerations to leg & hand shark PROVOKED INCIDENT',
#  'No injury, board bitten',
#  'FATAL',
#  'Minor injury to foot. PROVOKED INCIDENT',
#  'Lower left leg bitten',
#  'Minor injury to foot',
#  'Minor bite to hand by captive shark. PROVOKED INCIDENT',
#  'Injuries to lower right leg and foot',
#  'Severe bite to right forearm',
#  'Injured by teeth of a dead porbeagle shark he was tossing overboard.',
#  'Shallow lacerations to finger PROVOKED INCIDENT',
#  'Minor injury, marks on board',
#  'No injury, surfboard damaged',
#  'Minor injury to ankle',
#  'No injury, shark bit scuba gear',
#  'No injury, knocked off board by shark',
#  'No injury',
#  'No injury, shark struck his leg',
#  '5-inch cut to hand',
#  'No injury, shark bit hole in ski',
#  'Lacerations to right lower leg',
# ...

# %%
'''
Delete 'UNKNOWN', '2017',
Convert 'y' to 'Y'
Convert 'M' to 'N'
'''
unique_values['Fatal (Y/N)']
# Out:
# ['N', 'Y', nan, 'M', 'UNKNOWN', '2017', 'y']

# %%
'''
There's a lot to glean from here but not sure if it is worth doing
Circle back when analysing
'''
unique_values['Species '] # nothing to do here
# Out:
# ['White shark',
#  nan,
#  '2 m shark',
#  'Tiger shark, 3m',
#  'Tiger shark',
#  "Lemon shark, 3'",
#  "Bull shark, 6'",
#  'Grey reef shark',
#  'Invalid incident',
#  'Tawny nurse shark, 2m',
#  'Shark involvement not confirmed',
#  'Questionable',
#  '3 m shark',
#  'White shark, 3.5 m',
#  'White shark, 2.5 m',
#  "6' shark",
#  'Juvenile bull shark',
#  'Bull shark',
#  "Tiger shark, 12'",
#  'Wobbegong shark',
#  '3.5 m shark',
#  '1.8 m shark',
#  'Blacktip shark',
#  'Juvenile white shark,  2.7 to 3.2 m',
#  'Bull shark, 2 m',
#  'Possibly a wobbegong',
#  'Injury believed caused by an eel, not a shark',
#  'Galapagos shark?',
#  '2m shark',
#  'Bull shark, 3 m',
#  'Grey reef shark. 2 m',
#  'small shark',
#  'Wobbegong shark?',
#  'Juvenile nurse shark',
#  "Nurse shark. 5'",
#  'Tiger shark, female',
#  'Some drowned but other may have been killed by blue sharks',
#  'White shark, 4.6 m',
#  'Cookiecutter shark',
#  'Wobbegong shark, 1 m',
#  'White shark, 4.5 m',
# ...
